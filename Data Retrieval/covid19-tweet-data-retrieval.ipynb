# %%
import os
import tweepy as tw
import pandas as pd

# %%
consumer_key= 'aCMQbli3Ucbk5fzNvUY1YzwNe'
consumer_secret= 'An4nbBRt3s78DBYBbSwdSJnaSR1XX8vByfDIaulzYRLRXpl9Jc'
access_token= '1357318438469984256-zWGkD0ftGtDncUdDSZl8YXWX0o1g3b'
access_token_secret= 'SDPYPFATKrhac97elEtrtCU2q1mddDkGhRBWTpQw8AuDq'

# %%
auth = tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Post a tweet from Python
# api.update_status("Look, I'm tweeting from #Python in my #earthanalytics class! @EarthLabCU")
# Your tweet has been posted!

# %%
# Define the search term and the date_since date as variables
search_words = "#Covid-19"
date_since = "2021-02-01"

# %%
new_search = search_words + " -filter:retweets"
new_search
# '#wildfires -filter:retweets'
# Out:
# '#Covid-19 -filter:retweets'

# %%
tweets = tw.Cursor(api.search, 
                           q=new_search,
                           lang="en",
                           tweet_mode ='extended',
                           since=date_since).items(5000)

tweets_locs = [[tweet.created_at,tweet.id,tweet.full_text,tweet.entities['urls'],tweet.user.name] for tweet in tweets]
tweets_locs
# Out:
# [[datetime.datetime(2021, 2, 28, 13, 33, 40),
#   1366018733047619591,
#   '@Preetam_M_Rao Yogiji is probably THE best chief minister in the country today. His schemes to provide employment after the migrant workers crisis during the peak of the Covid-19 pandemic is simply exemplary. One lives in the state so am aware.',
#   [],
#   'Murli Menon'],
#  [datetime.datetime(2021, 2, 28, 13, 33, 38),
#   1366018728194793477,
#   "City to begin administering COVID-19 vaccines to those in Toronto's shelter\xa0system https://t.co/oyJ9L8eE6w",
#   [{'display_url': 'isfeed.com/city-to-begin-…',
#     'expanded_url': 'https://isfeed.com/city-to-begin-administering-covid-19-vaccines-to-those-in-torontos-shelter-system/',
#     'indices': [83, 106],
#     'url': 'https://t.co/oyJ9L8eE6w'}],
#   'ISFeed'],
#  [datetime.datetime(2021, 2, 28, 13, 33, 38),
#   1366018725552529408,
#   "FDA grants emergency use authorization for Johnson &amp; Johnson's COVID-19 vaccine.",
#   [],
#   'Donald Hodge'],
# ...

# %%
tweet_text = pd.DataFrame(data=tweets_locs, 
                    columns=['created_at', "tweet_id","text","url","username"])
tweet_text
# Out:
#               created_at  ...              username
# 0    2021-02-28 13:33:40  ...           Murli Menon
# 1    2021-02-28 13:33:38  ...                ISFeed
# 2    2021-02-28 13:33:38  ...          Donald Hodge
# 3    2021-02-28 13:33:36  ...       Mahendra Pandya
# 4    2021-02-28 13:33:34  ...               ጆን አብረሓ
# ...                  ...  ...                   ...
# 4995 2021-02-28 11:10:00  ...                  WTOP
# 4996 2021-02-28 11:10:00  ...    Marcella Robertson
# 4997 2021-02-28 11:10:00  ...           Yahoo India
# 4998 2021-02-28 11:10:00  ...          The Currency
# 4999 2021-02-28 11:10:00  ...  ABS-CBN News Channel
#
# [5000 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
tweet_text.to_csv(r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/Covid19_raw_data.csv', encoding='utf-8-sig', index=False)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(tweet_text, test_size = 0.2)

# %%
train = train.sort_index()

# %%
train
# Out:
#               created_at  ...              username
# 0    2021-02-28 13:33:40  ...           Murli Menon
# 1    2021-02-28 13:33:38  ...                ISFeed
# 2    2021-02-28 13:33:38  ...          Donald Hodge
# 3    2021-02-28 13:33:36  ...       Mahendra Pandya
# 4    2021-02-28 13:33:34  ...               ጆን አብረሓ
# ...                  ...  ...                   ...
# 4995 2021-02-28 11:10:00  ...                  WTOP
# 4996 2021-02-28 11:10:00  ...    Marcella Robertson
# 4997 2021-02-28 11:10:00  ...           Yahoo India
# 4998 2021-02-28 11:10:00  ...          The Currency
# 4999 2021-02-28 11:10:00  ...  ABS-CBN News Channel
#
# [4000 rows x 5 columns]

# %%
train.to_csv(r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/Covid19_train_data.csv', encoding='utf-8-sig', index=False)

# %%
test = test.sort_index()

# %%
test
# Out:
#               created_at  ...              username
# 14   2021-02-28 13:33:10  ...       Scott hollander
# 18   2021-02-28 13:33:05  ...           The Courier
# 28   2021-02-28 13:32:46  ...    Exegete Seph Moses
# 29   2021-02-28 13:32:46  ...      Dolphin Products
# 40   2021-02-28 13:32:31  ...           NRT English
# ...                  ...  ...                   ...
# 4983 2021-02-28 11:10:09  ...            Naijamerit
# 4984 2021-02-28 11:10:07  ...           steven gray
# 4988 2021-02-28 11:10:03  ...  SocialMediaMarketing
# 4991 2021-02-28 11:10:02  ...                omvapt
# 4994 2021-02-28 11:10:01  ...              Bizitalk
#
# [1000 rows x 5 columns]

# %%
test.to_csv(r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/Covid19_test_data.csv', encoding='utf-8-sig', index=False)

# %%
import pandas as pd

traindf = pd.read_csv("/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/Covid19_train_data.csv")

# %%
traindf
# Out:
#                created_at  ...              username
# 0     2021-02-28 13:33:40  ...           Murli Menon
# 1     2021-02-28 13:33:38  ...                ISFeed
# 2     2021-02-28 13:33:38  ...          Donald Hodge
# 3     2021-02-28 13:33:36  ...       Mahendra Pandya
# 4     2021-02-28 13:33:34  ...               ጆን አብረሓ
# ...                   ...  ...                   ...
# 3995  2021-02-28 11:10:00  ...                  WTOP
# 3996  2021-02-28 11:10:00  ...    Marcella Robertson
# 3997  2021-02-28 11:10:00  ...           Yahoo India
# 3998  2021-02-28 11:10:00  ...          The Currency
# 3999  2021-02-28 11:10:00  ...  ABS-CBN News Channel
#
# [4000 rows x 5 columns]

# %%
traindf_tua_1333 = traindf.head(1333)

# %%
traindf_tua_1333
# Out:
#                created_at  ...                  username
# 0     2021-02-28 13:33:40  ...               Murli Menon
# 1     2021-02-28 13:33:38  ...                    ISFeed
# 2     2021-02-28 13:33:38  ...              Donald Hodge
# 3     2021-02-28 13:33:36  ...           Mahendra Pandya
# 4     2021-02-28 13:33:34  ...                   ጆን አብረሓ
# ...                   ...  ...                       ...
# 1328  2021-02-28 12:52:02  ...              Head to Head
# 1329  2021-02-28 12:52:01  ...                  HT Delhi
# 1330  2021-02-28 12:52:00  ...       Devil's Cider Games
# 1331  2021-02-28 12:51:56  ...           Fabienne Oswald
# 1332  2021-02-28 12:51:56  ...  Franklin County Iowa GOP
#
# [1333 rows x 5 columns]

# %%
traindf_tua_1333.to_csv(r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/split_data_for_fill_label/traindf_tua_1333.csv', encoding='utf-8-sig', index=False)

# %%
traindf_pat_1333 = traindf[1333:2666]

# %%
traindf_pat_1333
# Out:
#                created_at  ...                            username
# 1333  2021-02-28 12:51:53  ...                     Hindustan Times
# 1334  2021-02-28 12:51:47  ...                    DisasterWildCard
# 1335  2021-02-28 12:51:46  ...               Abdullahi A Abdullahi
# 1336  2021-02-28 12:51:40  ...                       VishwajitRane
# 1337  2021-02-28 12:51:40  ...                    Terre' Lickfield
# ...                   ...  ...                                 ...
# 2661  2021-02-28 12:00:54  ...                 Bucks County Herald
# 2662  2021-02-28 12:00:54  ...                             InfoApp
# 2663  2021-02-28 12:00:53  ...  Fermanagh & Omagh District Council
# 2664  2021-02-28 12:00:53  ...                           BotWeekly
# 2665  2021-02-28 12:00:53  ...                        Maui Coupons
#
# [1333 rows x 5 columns]

# %%
traindf_pat_1333.to_csv(r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/split_data_for_fill_label/traindf_pat_1333.csv', encoding='utf-8-sig', index=False)

# %%
traindf_tukta_1333 = traindf.tail(1334)

# %%
traindf_tukta_1333
# Out:
#                created_at  ...              username
# 2666  2021-02-28 12:00:51  ...             SpeedBird
# 2667  2021-02-28 12:00:51  ...            marshy1508
# 2668  2021-02-28 12:00:51  ...        Independent.ie
# 2669  2021-02-28 12:00:51  ...            Brian Shaw
# 2670  2021-02-28 12:00:50  ...                News24
# ...                   ...  ...                   ...
# 3995  2021-02-28 11:10:00  ...                  WTOP
# 3996  2021-02-28 11:10:00  ...    Marcella Robertson
# 3997  2021-02-28 11:10:00  ...           Yahoo India
# 3998  2021-02-28 11:10:00  ...          The Currency
# 3999  2021-02-28 11:10:00  ...  ABS-CBN News Channel
#
# [1334 rows x 5 columns]

# %%
traindf_tukta_1333.to_csv(r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/split_data_for_fill_label/traindf_tukta_1333.csv', encoding='utf-8-sig', index=False)

# %%
import pandas as pd
import glob

path = r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/split_data_for_fill_label/completed_data_label' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#       Unnamed: 0  ... class_label
# 0              0  ...         HAM
# 1              1  ...        SPAM
# 2              2  ...        SPAM
# 3              3  ...        SPAM
# 4              4  ...         HAM
# ...          ...  ...         ...
# 3995        1328  ...        SPAM
# 3996        1329  ...        SPAM
# 3997        1330  ...        SPAM
# 3998        1331  ...         HAM
# 3999        1332  ...         NaN
#
# [4000 rows x 7 columns]

# %%
frame.to_csv(r'/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/split_data_for_fill_label/completed_data_label/covid19-train-data.csv', encoding='utf-8-sig', index=False)
