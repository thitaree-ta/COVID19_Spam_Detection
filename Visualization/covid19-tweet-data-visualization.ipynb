# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
traindf = pd.read_csv('/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/final_dataset/covid19-train-data.csv')

# %%
testdf = pd.read_csv('/content/gdrive/Shareddrives/CSC531-DM/Term Project/Datasets/raw_data_two/final_dataset/covid19_test_data.csv')

# %%
traindf
# Out:
#                                                    text class_label
# 0     The first batch of COVID-19 vaccines arrive at...         HAM
# 1     After the queens message spectacularly backfir...        SPAM
# 2     Supermarket workers are "the unsung heroes", a...        SPAM
# 3     @LeoVaradkar @gavreilly @NewstalkFM Will you b...        SPAM
# 4     Newer variants are spreading more easily and q...         HAM
# ...                                                 ...         ...
# 3995  The Egoavil family is doing well, despite its ...        SPAM
# 3996  Those  Doomsday Planes  Have Nothing to Do Wit...        SPAM
# 3997  Do you know the symptoms of coronavirus? \n\nI...        SPAM
# 3998  3: URL: https://t.co/Th7HXAKICa\nThe authoriza...         HAM
# 3999  HAWAII AIRPORTS CORONAVIRUS (COVID-19) UPDATES...        SPAM
#
# [4000 rows x 2 columns]

# %%
testdf
# Out:
#                                                   text
# 0    but apparently 500,000 dead from mishandled Co...
# 1    Visit the Courier's COVID-19 resource page for...
# 2    VIPERS TRANSFORMING FROM OLD TO NEW EVANGELISM...
# 3    A call to adapt the construction sector  to th...
# 4    237 new cases of COVID-19 recorded in Kurdista...
# ..                                                 ...
# 995  COVID-19: SERAP writes Adamu, seeks probe of ‘...
# 996  @rachie1788 @Matthew82069336 @piersmorgan Suic...
# 997  In The Post COVID-19 World, Zoom Is Here To St...
# 998  #Health #Website Leaks 8 #Million #COVID_19 #T...
# 999  You need 35 years of #NICs to get the full sta...
#
# [1000 rows x 1 columns]

# %%
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")

# %%
traindf.groupby('class_label').describe().T
# Out:
# class_label                                                HAM                                               SPAM
# text count                                                 975                                               3023
#      unique                                                972                                               3005
#      top     With the COVID-19 vaccinations set to begin so...  .@vonderleyen The #TRIPSwaiver on COVID-19 Int...
#      freq                                                    3                                                  4

# %%
ax = sns.countplot(x="class_label", data=traindf)

# %%
import re
traindf['cleanLinks'] = traindf['text'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
clean_Links = pd.DataFrame(data=traindf['cleanLinks'], 
                    columns=["cleanLinks"])

# %%
clean_Links

# %%
lower_case = cleanLinks['cleanLinks'].str.lower()

# %%
lower_case

# %%
set(lower_case)

# %%
lowercase[0].split()

# %%
words_in_tweet = [tweet.lower().split() for tweet in lowercase]

# %%
words_in_tweet[:4000]

# %%
import itertools
import collections

# List of all words across tweets
all_words_no_urls = list(itertools.chain(*words_in_tweet))

# Create counter
counts_no_urls = collections.Counter(all_words_no_urls)

counts_no_urls.most_common(15)

# %%
clean_tweets_no_urls = pd.DataFrame(counts_no_urls.most_common(15),
                             columns=['words', 'count'])

clean_tweets_no_urls[:15]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_no_urls.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in Tweets (Including All Words)")

plt.show()

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')

# %%
stop_words = set(stopwords.words('english'))

# View a few words from the set
list(stop_words)[0:1000000000000000000000]

# %%
# Remove stop words from each tweet list of words
tweets_nsw = [[word for word in tweet_words if not word in stop_words]
              for tweet_words in words_in_tweet]

tweets_nsw[0]

# %%
all_words_nsw = list(itertools.chain(*tweets_nsw))

counts_nsw = collections.Counter(all_words_nsw)

counts_nsw.most_common(15)

# %%
clean_tweets_nsw = pd.DataFrame(counts_nsw.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_nsw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in Tweets (Without Stop Words)")

plt.show()

# %%
collection_words = ['covid19', '#covid19','covid-19.','covid','-','19','&amp;','covid-19:','vaccines']

# %%
tweets_nsw_nc = [[w for w in word if not w in collection_words]
                 for word in tweets_nsw]

# %%
tweets_nsw[0]

# %%
tweets_nsw_nc[0]

# %%
# Flatten list of words in clean tweets
all_words_nsw_nc = list(itertools.chain(*tweets_nsw_nc))

# Create counter of words in clean tweets
counts_nsw_nc = collections.Counter(all_words_nsw_nc)

counts_nsw_nc.most_common(15)

# %%
len(counts_nsw_nc)

# %%
clean_tweets_ncw = pd.DataFrame(counts_nsw_nc.most_common(15),
                             columns=['words', 'count'])
clean_tweets_ncw.head()

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_ncw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in Tweets (Without Stop or Collection Words)")

plt.show()
